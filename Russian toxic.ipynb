# %% [markdown]
# <a href="https://colab.research.google.com/github/Vitalyastiy/NPS/blob/main/Russian%20toxic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# !pip install torch
# !pip install evaluate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
reviews = pd.read_excel('test.xlsx')
df = reviews.dropna()

# %%
from transformers import pipeline

clf = pipeline(
    task = 'sentiment-analysis', 
    model = 'SkolkovoInstitute/russian_toxicity_classifier')

#text = ['пятигорск']
#clf(text)

# %%
def fix_addr(text):
    matches = clf(text)
    return matches #(', '.join(f'{match or ""} {match}' for match in matches)) or None
df['city']=df['mark_6'].map(fix_addr)
df
# Out:
# <ipython-input-67-96210c6cc4c3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['city']=df['mark_6'].map(fix_addr)
#       create_date                                             mark_6  nps  \
# 0      2022-12-23                                                  3    0
# 5      2023-01-11                     г.Черноголовка, ул.Первая,д.25    0
# 6      2022-12-02                                                 10    1
# 14     2022-12-19  У меня тариф вообще дорогой но не хватает мега...    0
# 17     2022-12-16                                          мариуполь    1
# ...           ...                                                ...  ...
# 18621  2022-12-02                                                  3    1
# ...

# %%
classifier = pipeline("sentiment-analysis", model="blanchefort/rubert-base-cased-sentiment")

# %%
def fix_addr(text):
    matches = classifier(text)
    return matches #(', '.join(f'{match or ""} {match}' for match in matches)) or None
df['city']=df['mark_6'].map(fix_addr)
df

# %%
classifier = pipeline("sentiment-analysis", model="Tatyana/rubert-base-cased-sentiment-new")

# %%
def fix_addr(text):
    matches = classifier(text)
    return matches #(', '.join(f'{match or ""} {match}' for match in matches)) or None
df['city']=df['mark_6'].map(fix_addr)
df
# Out:
# <ipython-input-23-cdc11c3fdc56>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['city']=df['mark_6'].map(fix_addr)
#       create_date                                             mark_6  nps  \
# 0      2022-12-23                                                  3    0
# 5      2023-01-11                     г.Черноголовка, ул.Первая,д.25    0
# 6      2022-12-02                                                 10    1
# 14     2022-12-19  У меня тариф вообще дорогой но не хватает мега...    0
# 17     2022-12-16                                          мариуполь    1
# ...           ...                                                ...  ...
# 18621  2022-12-02                                                  3    1
# ...

# %%
df.to_excel("output.xlsx")
